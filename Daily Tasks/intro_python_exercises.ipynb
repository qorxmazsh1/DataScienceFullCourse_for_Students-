# %%
''' What are the results of the following expressions?
 10 + 5 * 3
 (10 + 5) * 3
 20 / 4
 20 // 4
 21 // 4
 21 % 4
 2 ** 5
'''

# %%
# Predict the output of the following expression without running it in Python: 5 + 3 * 2 - 8 / 4 ** 2

# %%
'''
Write Python code to check the following. Your code should print True or False.

Is 50 greater than 100?
Is 33 equal to 33.0?
Is "hello" not equal to "world"?
Is the length of "python" greater than or equal to 5?
'''

# %%
'''
Create a variable named city and assign it the value "New York".
Print the value of the city variable.
Change the value of city to "London" and print it again.
'''

# %%
'''
Create a variable score with a value of 100.
Using an assignment operator, subtract 25 from score.
Using an assignment operator, multiply score by 2.
Print the final score.

'''

# %%
'''
Which of the following variable names are invalid? Explain why.

1st_place
first-place
_first_place
for
FirstPlace
'''

# %%
'''
What is the data type of each of the following values?

99
"99"
99.0
False
None
'''

# %%
'''
You are given a variable price_str = "25.99". Convert it to a float and store it in a variable named price_float.
You have a variable quantity = 3. Convert it to a string.
Concatenate the string from step 2 with the text " items".
'''

# %%
'''Create two variables, first_name and last_name, with your names.
Create a full_name variable by concatenating them with a space in between.
Create a separator string that is 30 dashes (-) long using string replication.
Print the full_name and then the separator.'''

# %%
'''
Create a single string that, when printed, displays the following output:

  He said, "It's a beautiful day."

'''

# %%
'''Given the string s = "Programming is fun!":

What character is at index 4?
What is the last character of the string?
What substring do you get from slicing s[11:13]?
How can you get the substring "gram"?
How can you reverse the entire string?'''

# %%
'''
Given the string tweet = "  WOW, what a great game! #sports #python  ":

Convert the entire tweet to lowercase.
Remove the leading and trailing whitespace.
Replace "#python" with "#DataScience".
Split the cleaned tweet into a list of words.
'''

# %%
'''
User Greeting
Write a program that asks the user for their name.
Print a personalized greeting, like "Hello, [Name]!".
'''

# %%
'''
Age Calculator
Ask the user for the current year.
Ask the user for their birth year.
Calculate and print their age. Make sure to handle the input as numbers.
'''

# %%
'''Formatted Output
Create variables for item = "Laptop", price = 1200.50, and quantity = 2.
Calculate the total_cost.
Print a summary using an f-string that looks like this: Item: Laptop, Quantity: 2, Total Cost: $2,401.00 (Note the comma for thousands and two decimal places for the cost).'''
