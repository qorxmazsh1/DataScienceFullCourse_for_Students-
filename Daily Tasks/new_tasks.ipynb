# %%
Write a function that calculates the factorial of a given number n entered by the user.

# %%
Given a string where each word ends with a number indicating its correct position in the sentence, write a function to rearrange the sentence properly.

Input: "is2 sentence4 This1 a3"  
Output: "This is a sentence"

# %%
Write a function that replaces every "." in an IP address with "[.]".

Input: "192.168.0.1"  
Output: "192[.]168[.]0[.]1"

# %%
Write a function that checks whether a given number is a palindrome.
(A palindrome reads the same forward and backward.)

# %%
Given a string containing both words and numbers, write a function that extracts all numbers and returns their sum.

# %%
Write a function that finds the most frequently occurring character in a given string.
