# %%
Data Link:

https://www.kaggle.com/datasets/blastchar/telco-customer-churn

# %%
Task Description:
1. Load the dataset and perform basic exploratory data analysis (EDA) to understand the structure and characteristics of the data.
2. Preprocess the data by handling missing values, encoding categorical variables, and scaling numerical features as necessary.
3. Split the dataset into training and testing sets.
4. Train a machine learning model - Logistic Regression

# %%
shape
info
describe
value_counts
Missing values
Histograms
Boxplots
Countplots
Correlation heatmap
Feature engineering
Encoding
Train/Test split
Pipeline
Logistic Regression
